of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 4 | matay
# Processing Record 35 of Set 4 | lavrentiya
# Processing Record 36 of Set 4 | pangnirtung
# Processing Record 37 of Set 4 | dikson
# Processing Record 38 of Set 4 | tondon
# Processing Record 39 of Set 4 | mareeba
# Processing Record 40 of Set 4 | gladstone
# Processing Record 41 of Set 4 | nelson
# Processing Record 42 of Set 4 | talnakh
# Processing Record 43 of Set 4 | malakal
# Processing Record 44 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 45 of Set 4 | hammonton
# Processing Record 46 of Set 4 | kawalu
# Processing Record 47 of Set 4 | tshane
# Processing Record 48 of Set 4 | nurota
# Processing Record 49 of Set 4 | ambilobe
# Processing Record 0 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 5 | murmashi
# Processing Record 2 of Set 5 | saint-philippe
# Processing Record 3 of Set 5 | ugoofaaru
# Processing Record 4 of Set 5 | srednekolymsk
# Processing Record 5 of Set 5 | san patricio
# Processing Record 6 of Set 5 | ponta do sol
# Processing Record 7 of Set 5 | cidreira
# Processing Record 8 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 5 | karasburg
# Processing Record 10 of Set 5 | puerto escondido
# Processing Record 11 of Set 5 | tete
# Processing Record 12 of Set 5 | comodoro rivadavia
# Processing Record 13 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 5 | namatanai
# Processing Record 15 of Set 5 | lamu
# Processing Record 16 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 5 | tura
# Processing Record 18 of Set 5 | songjianghe
# Processing Record 19 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 5 | roebourne
# Processing Record 21 of Set 5 | sao filipe
# Processing Record 22 of Set 5 | upernavik
# Processing Record 23 of Set 5 | beidao
# Processing Record 24 of Set 5 | ewa beach
# Processing Record 25 of Set 5 | gamba
# Processing Record 26 of Set 5 | mandurah
# Processing Record 27 of Set 5 | sabha
# Processing Record 28 of Set 5 | kauhajoki
# Processing Record 29 of Set 5 | jumla
# Processing Record 30 of Set 5 | clyde river
# Processing Record 31 of Set 5 | kodinsk
# Processing Record 32 of Set 5 | sao domingos
# Processing Record 33 of Set 5 | dudinka
# Processing Record 34 of Set 5 | alta floresta
# Processing Record 35 of Set 5 | adrar
# Processing Record 36 of Set 5 | duobao
# Processing Record 37 of Set 5 | ipixuna
# Processing Record 38 of Set 5 | aksha
# Processing Record 39 of Set 5 | rocha
# Processing Record 40 of Set 5 | cairns
# Processing Record 41 of Set 5 | najran
# Processing Record 42 of Set 5 | verkhnyaya inta
# Processing Record 43 of Set 5 | flinders
# Processing Record 44 of Set 5 | mango
# Processing Record 45 of Set 5 | lorengau
# Processing Record 46 of Set 5 | warrnambool
# Processing Record 47 of Set 5 | nelson bay
# Processing Record 48 of Set 5 | baykit
# Processing Record 49 of Set 5 | serra talhada
# Processing Record 0 of Set 6 | okhotsk
# Processing Record 1 of Set 6 | fairbanks
# Processing Record 2 of Set 6 | bengkulu
# Processing Record 3 of Set 6 | fort nelson
# Processing Record 4 of Set 6 | ballina
# Processing Record 5 of Set 6 | el cobre
# Processing Record 6 of Set 6 | cap malheureux
# Processing Record 7 of Set 6 | iqaluit
# Processing Record 8 of Set 6 | faanui
# Processing Record 9 of Set 6 | abu samrah
# Processing Record 10 of Set 6 | kovdor
# Processing Record 11 of Set 6 | baglung
# Processing Record 12 of Set 6 | khani
# Processing Record 13 of Set 6 | bambous virieux
# Processing Record 14 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 6 | khandyga
# Processing Record 16 of Set 6 | hofn
# Processing Record 17 of Set 6 | kapoeta
# Processing Record 18 of Set 6 | usinsk
# Processing Record 19 of Set 6 | geraldton
# Processing Record 20 of Set 6 | mount gambier
# Processing Record 21 of Set 6 | annau
# Processing Record 22 of Set 6 | flagstaff
# Processing Record 23 of Set 6 | aasiaat
# Processing Record 24 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 6 | bethel
# Processing Record 26 of Set 6 | lugovoy
# Processing Record 27 of Set 6 | south lake tahoe
# Processing Record 28 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 29 of Set 6 | ibra
# Processing Record 30 of Set 6 | isiro
# Processing Record 31 of Set 6 | poum
# Processing Record 32 of Set 6 | souillac
# Processing Record 33 of Set 6 | torbay
# Processing Record 34 of Set 6 | majene
# Processing Record 35 of Set 6 | margate
# Processing Record 36 of Set 6 | biltine
# Processing Record 37 of Set 6 | eldorado
# Processing Record 38 of Set 6 | noumea
# Processing Record 39 of Set 6 | dali
# Processing Record 40 of Set 6 | demak
# Processing Record 41 of Set 6 | canutama
# Processing Record 42 of Set 6 | kirksville
# Processing Record 43 of Set 6 | sao joao da barra
# Processing Record 44 of Set 6 | hami
# Processing Record 45 of Set 6 | eydhafushi
# Processing Record 46 of Set 6 | hakui
# Processing Record 47 of Set 6 | chiredzi
# Processing Record 48 of Set 6 | port hedland
# Processing Record 49 of Set 6 | ivdel
# Processing Record 0 of Set 7 | armacao de pera
# Processing Record 1 of Set 7 | hasaki
# Processing Record 2 of Set 7 | hualmay
# Processing Record 3 of Set 7 | akyab
# Processing Record 4 of Set 7 | luderitz
# Processing Record 5 of Set 7 | hervey bay
# Processing Record 6 of Set 7 | bilibino
# Processing Record 7 of Set 7 | yuci
# Processing Record 8 of Set 7 | kaeo
# Processing Record 9 of Set 7 | marly
# Processing Record 10 of Set 7 | takaka
# Processing Record 11 of Set 7 | gossaigaon
# Processing Record 12 of Set 7 | monrovia
# Processing Record 13 of Set 7 | jishou
# Processing Record 14 of Set 7 | alofi
# Processing Record 15 of Set 7 | abu dhabi
# Processing Record 16 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 17 of Set 7 | harper
# Processing Record 18 of Set 7 | yar-sale
# Processing Record 19 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 7 | wau
# Processing Record 21 of Set 7 | yefremov
# Processing Record 22 of Set 7 | winnemucca
# Processing Record 23 of Set 7 | payo
# Processing Record 24 of Set 7 | vanimo
# Processing Record 25 of Set 7 | alabaster
# Processing Record 26 of Set 7 | mbandaka
# Processing Record 27 of Set 7 | evanton
# Processing Record 28 of Set 7 | neuquen
# Processing Record 29 of Set 7 | buin
# Processing Record 30 of Set 7 | seoul
# Processing Record 31 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 7 | kalat
# Processing Record 33 of Set 7 | vila franca do campo
# Processing Record 34 of Set 7 | fougamou
# Processing Record 35 of Set 7 | eureka
# Processing Record 36 of Set 7 | inta
# Processing Record 37 of Set 7 | castro
# Processing Record 38 of Set 7 | chistogorskiy
# Processing Record 39 of Set 7 | kieta
# Processing Record 40 of Set 7 | sola
# Processing Record 41 of Set 7 | ambon
# Processing Record 42 of Set 7 | bambanglipuro
# Processing Record 43 of Set 7 | half moon bay
# Processing Record 44 of Set 7 | lagunas
# Processing Record 45 of Set 7 | oksbol
# Processing Record 46 of Set 7 | kano
# Processing Record 47 of Set 7 | waingapu
of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 29 of Set 9 | svetlyy
# Processing Record 30 of Set 9 | port-gentil
# Processing Record 31 of Set 9 | vestmannaeyjar
# Processing Record 32 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 9 | bundaberg
# Processing Record 34 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 9 | koulikoro
# Processing Record 36 of Set 9 | asau
# Processing Record 37 of Set 9 | victor harbor
# Processing Record 38 of Set 9 | moose factory
# Processing Record 39 of Set 9 | gemena
# Processing Record 40 of Set 9 | broome
# Processing Record 41 of Set 9 | mackay
# Processing Record 42 of Set 9 | amazar
# Processing Record 43 of Set 9 | sibu
# Processing Record 44 of Set 9 | salaga
# Processing Record 45 of Set 9 | ust-tsilma
# Processing Record 46 of Set 9 | puerto del rosario
# Processing Record 47 of Set 9 | raton
# Processing Record 48 of Set 9 | boa vista
# Processing Record 49 of Set 9 | shihezi
# Processing Record 0 of Set 10 | along
# Processing Record 1 of Set 10 | kisangani
# Processing Record 2 of Set 10 | wagar
# Processing Record 3 of Set 10 | esperance
# Processing Record 4 of Set 10 | luena
# Processing Record 5 of Set 10 | nuevo progreso
# Processing Record 6 of Set 10 | berdigestyakh
# Processing Record 7 of Set 10 | deputatskiy
# Processing Record 8 of Set 10 | maumere
# Processing Record 9 of Set 10 | karratha
# Processing Record 10 of Set 10 | la ronge
# Processing Record 11 of Set 10 | volovo
# Processing Record 12 of Set 10 | atar
# Processing Record 13 of Set 10 | rondonopolis
# Processing Record 14 of Set 10 | saint-augustin
# Processing Record 15 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 10 | puri
# Processing Record 17 of Set 10 | nome
# Processing Record 18 of Set 10 | cabedelo
# Processing Record 19 of Set 10 | luanda
# Processing Record 20 of Set 10 | oistins
# Processing Record 21 of Set 10 | port pirie
# Processing Record 22 of Set 10 | miro khan
# Processing Record 23 of Set 10 | kulhudhuffushi
# Processing Record 24 of Set 10 | saint-joseph
# Processing Record 25 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 26 of Set 10 | vestmanna
# Processing Record 27 of Set 10 | kendari
# Processing Record 28 of Set 10 | inirida
# Processing Record 29 of Set 10 | lashio
# Processing Record 30 of Set 10 | foz
# Processing Record 31 of Set 10 | namuac
# Processing Record 32 of Set 10 | deep river
# Processing Record 33 of Set 10 | jiutai
# Processing Record 34 of Set 10 | bathsheba
# Processing Record 35 of Set 10 | nemuro
# Processing Record 36 of Set 10 | soyo
# Processing Record 37 of Set 10 | cockburn town
# Processing Record 38 of Set 10 | coihaique
# Processing Record 39 of Set 10 | san policarpo
# Processing Record 40 of Set 10 | komsomolets
# Processing Record 41 of Set 10 | anzoategui
# Processing Record 42 of Set 10 | kharitonovo
# Processing Record 43 of Set 10 | touros
# Processing Record 44 of Set 10 | klaksvik
# Processing Record 45 of Set 10 | bogorodskoye
# Processing Record 46 of Set 10 | zyryanka
# Processing Record 47 of Set 10 | sao jose da coroa grande
# Processing Record 48 of Set 10 | maskinonge
# Processing Record 49 of Set 10 | mugur-aksy
# Processing Record 0 of Set 11 | havre-saint-pierre
# Processing Record 1 of Set 11 | amarante do maranhao
# Processing Record 2 of Set 11 | kamennomostskoye
# Processing Record 3 of Set 11 | praia
# Processing Record 4 of Set 11 | obo
# Processing Record 5 of Set 11 | russkaya polyana
# Processing Record 6 of Set 11 | katherine
# Processing Record 7 of Set 11 | cacador
# Processing Record 8 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 9 of Set 11 | dukat
# Processing Record 10 of Set 11 | athabasca
# Processing Record 11 of Set 11 | virden
# Processing Record 12 of Set 11 | ingham
# Processing Record 13 of Set 11 | sangar
# Processing Record 14 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 15 of Set 11 | perth
# Processing Record 16 of Set 11 | igarka
# Processing Record 17 of Set 11 | adre
# Processing Record 18 of Set 11 | puerto madryn
# Processing Record 19 of Set 11 | hanko
# Processing Record 20 of Set 11 | krasnoborsk
# Processing Record 21 of Set 11 | kozlovo
# Processing Record 22 of Set 11 | acarau
# Processing Record 23 of Set 11 | sibolga
# Processing Record 24 of Set 11 | tautira
# Processing Record 25 of Set 11 | meadow lake
# Processing Record 26 of Set 11 | college
# Processing Record 27 of Set 11 | santa rosa
# Processing Record 28 of Set 11 | teutonia
# Processing Record 29 of Set 11 | bojaya
# City not found. Skipping...
# Processing Record 30 of Set 11 | san jose
# Processing Record 31 of Set 11 | maua
# Processing Record 32 of Set 11 | vangaindrano
# Processing Record 33 of Set 11 | shingu
# Processing Record 34 of Set 11 | ust-kuyga
# Processing Record 35 of Set 11 | porto novo
# Processing Record 36 of Set 11 | yatou
# Processing Record 37 of Set 11 | erenhot
# Processing Record 38 of Set 11 | canon city
# Processing Record 39 of Set 11 | manoel urbano
# Processing Record 40 of Set 11 | takapau
# Processing Record 41 of Set 11 | meulaboh
# Processing Record 42 of Set 11 | laguna
# Processing Record 43 of Set 11 | mpulungu
# Processing Record 44 of Set 11 | oranjestad
# Processing Record 45 of Set 11 | mosquera
# Processing Record 46 of Set 11 | faya
# Processing Record 47 of Set 11 | kindu
# Processing Record 48 of Set 11 | bamako
# Processing Record 49 of Set 11 | maragogi
# Processing Record 0 of Set 12 | springfield
# Processing Record 1 of Set 12 | salalah
# Processing Record 2 of Set 12 | mercedes
# Processing Record 3 of Set 12 | wewak
# Processing Record 4 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 12 | centralia
# Processing Record 6 of Set 12 | kajaani
# Processing Record 7 of Set 12 | baymak
# Processing Record 8 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 9 of Set 12 | kavieng
# Processing Record 10 of Set 12 | huangzhai
# Processing Record 11 of Set 12 | lebedinyy
# Processing Record 12 of Set 12 | dan khun thot
# Processing Record 13 of Set 12 | heihe
# Processing Record 14 of Set 12 | asuncion nochixtlan
# Processing Record 15 of Set 12 | bafq
# Processing Record 16 of Set 12 | saint-louis
# Processing Record 17 of Set 12 | san pedro de los naranjos
# Processing Record 18 of Set 12 | luceville
# City not found. Skipping...
# Processing Record 19 of Set 12 | gold coast
# Processing Record 20 of Set 12 | mahon
# Processing Record 21 of Set 12 | baherden
# Processing Record 22 of Set 12 | ust-maya
# Processing Record 23 of Set 12 | lubawa
# Processing Record 24 of Set 12 | hof
# Processing Record 25 of Set 12 | burgersdorp
# Processing Record 26 of Set 12 | baboua
# City not found. Skipping...
# Processing Record 27 of Set 12 | haines junction
# Processing Record 28 of Set 12 | luis correia
# Processing Record 29 of Set 12 | taitung
# Processing Record 30 of Set 12 | yarmouth
# Processing Record 31 of Set 12 | xichang
# Processing Record 32 of Set 12 | lake charles
# Processing Record 33 of Set 12 | nam tha
# City not found. Skipping...
# Processing Record 34 of Set 12 | tynda
# Processing Record 35 of Set 12 | shreveport
# Processing Record 36 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 12 | kayes
# Processing Record 38 of Set 12 | nylstroom
# City not found. Skipping...
# Processing Record 39 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 12 | kaduqli
# Processing Record 41 of Set 12 | hidalgo
# Processing Record 42 of Set 12 | grand gaube
# Processing Record 43 of Set 12 | caranavi
# Processing Record 44 of Set 12 | ixtapa
# Processing Record 45 of Set 12 | likasi
# Processing Record 46 of Set 12 | gurupa
# Processing Record 47 of Set 12 | doha
# Processing Record 48 of Set 12 | morehead
# Processing Record 49 of Set 12 | rivers
# Processing Record 0 of Set 13 | matara
# Processing Record 1 of Set 13 | grindavik
# Processing Record 2 of Set 13 | westport
# Processing Record 3 of Set 13 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 4 of Set 13 | ous
# Processing Record 5 of Set 13 | manaure
# Processing Record 6 of Set 13 | karoi
# Processing Record 7 of Set 13 | narok
# Processing Record 8 of Set 13 | wum
# Processing Record 9 of Set 13 | vitry-le-francois
# Processing Record 10 of Set 13 | holbeach
# Processing Record 11 of Set 13 | erzin
# Processing Record 12 of Set 13 | ajtos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame

city_data_df = pd.DataFrame(city_data, columns=["City","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Country","Date"])

# Show Record Count
city_data_df.count()
# Out:
# City          564
# Lat           564
# Lng           564
# Max Temp      564
# Humidity      564
# Cloudiness    564
# Wind Speed    564
# Country       564
# Date          564
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         lagoa  39.0500  -27.9833     19.87        75          73
# 1          lasa  46.6166   10.7002     23.35        35           0
# 2      khatanga  71.9667  102.5000     16.74        35          54
# 3     saskylakh  71.9167  114.0833     11.84        54          39
# 4  puerto ayora  -0.7393  -90.3518     24.75        95          97
#
#    Wind Speed Country        Date
# 0        2.87      PT  1687683634
# 1        1.12      IT  1687683635
# 2        4.60      RU  1687683635
# 3        4.64      RU  1687683636
# 4        1.79      EC  1687683637

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               lagoa  39.0500  -27.9833     19.87        75          73
# 1                lasa  46.6166   10.7002     23.35        35           0
# 2            khatanga  71.9667  102.5000     16.74        35          54
# 3           saskylakh  71.9167  114.0833     11.84        54          39
# 4        puerto ayora  -0.7393  -90.3518     24.75        95          97
#
#          Wind Speed Country        Date
# City_ID
# 0              2.87      PT  1687683634
# 1              1.12      IT  1687683635
# 2              4.60      RU  1687683635
# 3              4.64      RU  1687683636
# 4              1.79      EC  1687683637

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

# Incorporate the other graph properties

city_data_df.plot.scatter("Lat", "Max Temp",title="City Max Latitude vs. Temperature (2023-6-25)", grid=True)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save the figure
plt.savefig("output_data/Fig1.png", dpi = 150)

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# Incorporate the other graph properties

city_data_df.plot.scatter("Lat", "Humidity",title="City Latitude vs. Humidity (2023-6-18)", grid=True)
plt.xlabel("Latitude")
plt.ylabel("HUmidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# Incorporate the other graph properties

city_data_df.plot.scatter("Lat", "Cloudiness",title="City Latitude vs. Cloudiness (2023-6-18)", grid=True)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# Incorporate the other graph properties

city_data_df.plot.scatter("Lat", "Wind Speed",title="City Latitude vs. Cloudiness (2023-6-18)", grid=True)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.drop(city_data_df[city_data_df["Lat"] < 0].index)

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              lagoa  39.0500  -27.9833     19.87        75          73
# 1               lasa  46.6166   10.7002     23.35        35           0
# 2           khatanga  71.9667  102.5000     16.74        35          54
# 3          saskylakh  71.9167  114.0833     11.84        54          39
# 9        provideniya  64.3833 -173.3000     11.01        83          93
#
#          Wind Speed Country        Date
# City_ID
# 0              2.87      PT  1687683634
# 1              1.12      IT  1687683635
# 2              4.60      RU  1687683635
# 3              4.64      RU  1687683636
# 9              0.90      RU  1687683639

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.drop(city_data_df[city_data_df["Lat"] >= 0].index)

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4        puerto ayora  -0.7393  -90.3518     24.75        95          97
# 5             ushuaia -54.8000  -68.3000     -0.19        86           0
# 6               vaini -21.2000 -175.2000     20.09        94          40
# 7            hermanus -34.4187   19.2345     12.67        95         100
# 8               ancud -41.8697  -73.8203     12.48        87         100
#
#          Wind Speed Country        Date
# City_ID
# 4              1.79      EC  1687683637
# 5              1.54      AR  1687683637
# 6              1.03      TO  1687683638
# 7              4.36      ZA  1687683638
# 8             13.15      CL  1687683621

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

northern_hemi_df.plot.scatter("Lat", "Max Temp")
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.600933980778739

# %%
# Linear regression on Southern Hemisphere

southern_hemi_df.plot.scatter("Lat", "Max Temp")
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.8609119516409531

# %% [markdown]
# **Discussion about the linear relationship:** From the data of the North Hemisphere, there is a negative corelation between the tempature and the latitude: the higher the latitude, the lower the max temperature is. The absolute r-value for the North Hemisphere data is 0.6009, which has a moderate correlation.
# From the data of the South Hemisphere, there is a positive corelation between the tempature and the latitude: the higher the latitude, the higher the max temperature is. The absolute r-value for the South Hemisphere data is 0.8609, which has a strong correlation.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

northern_hemi_df.plot.scatter("Lat", "Humidity")
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.11012278202932396

# %%
# Southern Hemisphere

southern_hemi_df.plot.scatter("Lat", "Humidity")
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.1489926681726861

# %% [markdown]
# **Discussion about the linear relationship:** From both the data of the North and South Hemisphere, the absolute r-values for both data is between 0.1 and 0.15, which is lower than 0.3. According to the Pearson's correlation, there is a very weak to no correlation between the latitude and the humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

northern_hemi_df.plot.scatter("Lat", "Cloudiness")
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.03614528520306971

# %%
# Southern Hemisphere

southern_hemi_df.plot.scatter("Lat", "Cloudiness")
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.02501050745418159

# %% [markdown]
# **Discussion about the linear relationship:** From both the data of the North and South Hemisphere, the absolute r-values for both data is between 0.025 and 0.037, which is lower than 0.3. According to the Pearson's correlation, there is a very weak to no correlation between the latitude and the cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

northern_hemi_df.plot.scatter("Lat", "Wind Speed")
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.027599952278056082

# %%
# Southern Hemisphere

southern_hemi_df.plot.scatter("Lat", "Wind Speed")
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.15884015459715725

# %% [markdown]
# **Discussion about the linear relationship:** From both the data of the North and South Hemisphere, the absolute r-values for both data is between 0.0276 and 0.1588, which is lower than 0.3. According to the Pearson's correlation, there is a very weak to no correlation between the latitude and the wind speed.
